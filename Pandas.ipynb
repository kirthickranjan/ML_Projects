# %% [markdown]
# <a href="https://colab.research.google.com/github/kirthickranjan/ML_Projects/blob/main/Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
a=np.array([10,12,13,44,56])
a
# Out:
# array([10, 12, 13, 44, 56])

# %%
type(a)
# Out:
# numpy.ndarray

# %%
a[1]
# Out:
# 12

# %%
#Series is a 1D Ayyar
s=pd.Series([10,12,13,44,56])
type(s)
# Out:
# pandas.core.series.Series

# %%
s
# Out:
# 0    10
# 1    12
# 2    13
# 3    44
# 4    56
# dtype: int64

# %%
s[3]
# Out:
# 44

# %%
#To drop element
s.drop(3)
# Out:
# 0    10
# 1    12
# 2    13
# 4    56
# dtype: int64

# %%
s[3]
# Out:
# 44

# %%
s.drop(3,inplace=True)

# %%
s.iloc[3]
# Out:
# 56

# %%
s.loc[4]
# Out:
# 56

# %%
s.index
# Out:
# Int64Index([0, 1, 2, 4], dtype='int64')

# %%
ss=pd.Series([14,16,21,24,42],index=['Gokul','Guhan','Kathir','Kirthick','Sanjay'])
ss
# Out:
# Gokul       14
# Guhan       16
# Kathir      21
# Kirthick    24
# Sanjay      42
# dtype: int64

# %%
ss.loc['Kirthick']
# Out:
# 24

# %%
print(ss.iloc[2])
ss.iloc[1]
# Out:
# 21
# 16

# %%
data=[['Guhan',16,'22-08-2002'],['kathir',21,'12-09-2002'],['Kirthick',24,None],['Gokul',14,None],['Sanjay',42,None]]
data
# Out:
# [['Guhan', 16, '22-08-2002'],
#  ['kathir', 21, '12-09-2002'],
#  ['Kirthick', 24, None],
#  ['Gokul', 14, None],
#  ['Sanjay', 42, None]]

# %%
df=pd.DataFrame(data)
df
# Out:
#           0   1           2
# 0     Guhan  16  22-08-2002
# 1    kathir  21  12-09-2002
# 2  Kirthick  24        None
# 3     Gokul  14        None
# 4    Sanjay  42        None

# %%
df[0:3]
# Out:
#           0   1           2
# 0     Guhan  16  22-08-2002
# 1    kathir  21  12-09-2002
# 2  Kirthick  24        None

# %%
print(df[0][2])
print()
print(df[0][4])
print()
# Out:
# Kirthick
#
# Sanjay

# %%
df[0]
# Out:
# 0       Guhan
# 1      kathir
# 2    Kirthick
# 3       Gokul
# 4      Sanjay
# Name: 0, dtype: object

# %%
data=[['Kavin',22,'15-10-2002'],['Kavinkumar',23,'07-04-2002'],['Naveen',None,None],['Yokesh',60,'24-06-2002'],['Sridhar',None,'05-03-2003'],['Tharun',55,None],['Gokul',14,'20-06-2003'],['Sanjay',42,None]]
data
# Out:
# [['Kavin', 22, '15-10-2002'],
#  ['Kavinkumar', 23, '07-04-2002'],
#  ['Naveen', None, None],
#  ['Yokesh', 60, '24-06-2002'],
#  ['Sridhar', None, '05-03-2003'],
#  ['Tharun', 55, None],
#  ['Gokul', 14, '20-06-2003'],
#  ['Sanjay', 42, None]]

# %%
df=pd.DataFrame(data,columns=['Name','Roll_no','DOB'])

# %%
df['Name'][0]
# Out:
# 'Kavin'

# %%
df[0:1]
# Out:
#     Name  Roll_no         DOB
# 0  Kavin     22.0  15-10-2002

# %%
s=pd.Series([1,2,3])
s.plot()
# Out:
# <Axes: >

# %%
s.hist(bins=2)
# Out:
# <Axes: >

# %%
type(s)
# Out:
# pandas.core.series.Series

# %%
s=s.to_numpy()

# %%
type(s)
# Out:
# numpy.ndarray

# %%
df.head(10)
# Out:
#          Name  Roll_no         DOB
# 0       Kavin     22.0  15-10-2002
# 1  Kavinkumar     23.0  07-04-2002
# 2      Naveen      NaN        None
# 3      Yokesh     60.0  24-06-2002
# 4     Sridhar      NaN  05-03-2003
# 5      Tharun     55.0        None
# 6       Gokul     14.0  20-06-2003
# 7      Sanjay     42.0        None

# %%
df.tail(-2)
# Out:
#       Name  Roll_no         DOB
# 2   Naveen      NaN        None
# 3   Yokesh     60.0  24-06-2002
# 4  Sridhar      NaN  05-03-2003
# 5   Tharun     55.0        None
# 6    Gokul     14.0  20-06-2003
# 7   Sanjay     42.0        None

# %%
df.tail(2)
# Out:
#      Name  Roll_no         DOB
# 6   Gokul     14.0  20-06-2003
# 7  Sanjay     42.0        None

# %%
#None '',' ','','-','?','Nil',np.nan (not a number)
df.isnull().sum()
# Out:
# Name       0
# Roll_no    2
# DOB        3
# dtype: int64

# %%
#drop none values
df.dropna()
# Out:
#          Name  Roll_no         DOB
# 0       Kavin     22.0  15-10-2002
# 1  Kavinkumar     23.0  07-04-2002
# 3      Yokesh     60.0  24-06-2002
# 6       Gokul     14.0  20-06-2003

# %%
df
# Out:
#          Name  Roll_no         DOB
# 0       Kavin     22.0  15-10-2002
# 1  Kavinkumar     23.0  07-04-2002
# 2      Naveen      NaN        None
# 3      Yokesh     60.0  24-06-2002
# 4     Sridhar      NaN  05-03-2003
# 5      Tharun     55.0        None
# 6       Gokul     14.0  20-06-2003
# 7      Sanjay     42.0        None

# %%
df.drop(['DOB'],axis=1,inplace=True)

# %%
df
# Out:
#          Name  Roll_no
# 0       Kavin     22.0
# 1  Kavinkumar     23.0
# 2      Naveen      NaN
# 3      Yokesh     60.0
# 4     Sridhar      NaN
# 5      Tharun     55.0
# 6       Gokul     14.0
# 7      Sanjay     42.0

# %%
df.drop([0,2])
# Out:
#          Name  Roll_no
# 1  Kavinkumar     23.0
# 3      Yokesh     60.0
# 4     Sridhar      NaN
# 5      Tharun     55.0
# 6       Gokul     14.0
# 7      Sanjay     42.0

# %%
a
# Out:
# array([10, 12, 13, 44, 56])

# %%
a>40
# Out:
# array([False, False, False,  True,  True])

# %%
a[a>40]
# Out:
# array([44, 56])

# %%
a[a%2!=0]
# Out:
# array([13])

# %%
df
# Out:
#          Name  Roll_no
# 0       Kavin     22.0
# 1  Kavinkumar     23.0
# 2      Naveen      NaN
# 3      Yokesh     60.0
# 4     Sridhar      NaN
# 5      Tharun     55.0
# 6       Gokul     14.0
# 7      Sanjay     42.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Name     8 non-null      object
#  1   Roll_no  6 non-null      float64
# dtypes: float64(1), object(1)
# memory usage: 256.0+ bytes

# %%
df['Name'].str.contains('e')
# Out:
# 0    False
# 1    False
# 2     True
# 3     True
# 4    False
# 5    False
# 6    False
# 7    False
# Name: Name, dtype: bool

# %%
df['Name'].str.contains('p')
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 6    False
# 7    False
# Name: Name, dtype: bool

# %%
print(df.shape)
print(df.size)
print(df.axes)
print(df.ndim)
print(df.dtypes)
print(df.index)
print(df.columns)
print(df.values)
# Out:
# (8, 2)
# 16
# [RangeIndex(start=0, stop=8, step=1), Index(['Name', 'Roll_no'], dtype='object')]
# 2
# Name        object
# Roll_no    float64
# dtype: object
# RangeIndex(start=0, stop=8, step=1)
# Index(['Name', 'Roll_no'], dtype='object')
# [['Kavin' 22.0]
#  ['Kavinkumar' 23.0]
#  ['Naveen' nan]
#  ['Yokesh' 60.0]
#  ['Sridhar' nan]
#  ['Tharun' 55.0]
#  ['Gokul' 14.0]
#  ['Sanjay' 42.0]]

# %%
df.describe(include='all')
# Out:
#          Name    Roll_no
# count       8   6.000000
# unique      8        NaN
# top     Kavin        NaN
# freq        1        NaN
# mean      NaN  36.000000
# std       NaN  19.089264
# min       NaN  14.000000
# 25%       NaN  22.250000
# 50%       NaN  32.500000
# 75%       NaN  51.750000
# max       NaN  60.000000

# %%
df1=pd.concat([df,df])

# %%
df1
# Out:
#          Name  Roll_no
# 0       Kavin     22.0
# 1  Kavinkumar     23.0
# 2      Naveen      NaN
# 3      Yokesh     60.0
# 4     Sridhar      NaN
# 5      Tharun     55.0
# 6       Gokul     14.0
# 7      Sanjay     42.0
# 0       Kavin     22.0
# 1  Kavinkumar     23.0
# 2      Naveen      NaN
# 3      Yokesh     60.0
# 4     Sridhar      NaN
# 5      Tharun     55.0
# 6       Gokul     14.0
# 7      Sanjay     42.0

# %%
df['Name']
# Out:
# 0         Kavin
# 1    Kavinkumar
# 2        Naveen
# 3        Yokesh
# 4       Sridhar
# 5        Tharun
# 6         Gokul
# 7        Sanjay
# Name: Name, dtype: object

# %%
df.loc[0][0]
# Out:
# 'Kavin'

# %%
df.loc[0,"Name"]
# Out:
# 'Kavin'

# %%
df.iloc[0,1]
# Out:
# 22.0

# %%
df1=pd.read_html("https://en.wikipedia.org/wiki/Java_(programming_language)")
df
# Out:
#          Name  Roll_no
# 0       Kavin     22.0
# 1  Kavinkumar     23.0
# 2      Naveen      NaN
# 3      Yokesh     60.0
# 4     Sridhar      NaN
# 5      Tharun     55.0
# 6       Gokul     14.0
# 7      Sanjay     42.0

# %%
df.describe()
# Out:
#          Roll_no
# count   6.000000
# mean   36.000000
# std    19.089264
# min    14.000000
# 25%    22.250000
# 50%    32.500000
# 75%    51.750000
# max    60.000000

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df2=pd.read_table("https://raw.githubusercontent.com/nunnarilabs/ml/master/pandas/chipotle.tsv");
df2
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
type(df2.item_name)
# Out:
# pandas.core.series.Series

# %%
df2.isnull().sum()
# Out:
# order_id                 0
# quantity                 0
# item_name                0
# choice_description    1246
# item_price               0
# dtype: int64

# %%
type(df2.item_price[0])
# Out:
# str

# %%
df2.item_price=df2.item_price.str.replace('$','')
df2.head(10)
# Out:
# <ipython-input-353-7035c8e4e50a>:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df2.item_price=df2.item_price.str.replace('$','')
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
# 5         3         1                           Chicken Bowl
# 6         3         1                          Side of Chips
# 7         4         1                          Steak Burrito
# 8         4         1                       Steak Soft Tacos
# 9         5         1                          Steak Burrito
#
# ...

# %%
df2.item_price=df2.item_price.astype(float)

# %%
df2
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description  item_price
# 0                                                   NaN        2.39
# ...

# %%
type(df2.item_price[0])
# Out:
# numpy.float64

# %%
df2.item_price*2
# Out:
# 0        4.78
# 1        6.78
# 2        6.78
# 3        4.78
# 4       33.96
#         ...
# 4617    23.50
# 4618    23.50
# 4619    22.50
# 4620    17.50
# 4621    17.50
# Name: item_price, Length: 4622, dtype: float64

# %%
df2
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description  item_price
# 0                                                   NaN        2.39
# ...

# %%
df2.item_name.unique()
# Out:
# array(['Chips and Fresh Tomato Salsa', 'Izze', 'Nantucket Nectar',
#        'Chips and Tomatillo-Green Chili Salsa', 'Chicken Bowl',
#        'Side of Chips', 'Steak Burrito', 'Steak Soft Tacos',
#        'Chips and Guacamole', 'Chicken Crispy Tacos',
#        'Chicken Soft Tacos', 'Chicken Burrito', 'Canned Soda',
#        'Barbacoa Burrito', 'Carnitas Burrito', 'Carnitas Bowl',
#        'Bottled Water', 'Chips and Tomatillo Green Chili Salsa',
#        'Barbacoa Bowl', 'Chips', 'Chicken Salad Bowl', 'Steak Bowl',
#        'Barbacoa Soft Tacos', 'Veggie Burrito', 'Veggie Bowl',
#        'Steak Crispy Tacos', 'Chips and Tomatillo Red Chili Salsa',
#        'Barbacoa Crispy Tacos', 'Veggie Salad Bowl',
#        'Chips and Roasted Chili-Corn Salsa',
#        'Chips and Roasted Chili Corn Salsa', 'Carnitas Soft Tacos',
#        'Chicken Salad', 'Canned Soft Drink', 'Steak Salad Bowl',
#        '6 Pack Soft Drink', 'Chips and Tomatillo-Red Chili Salsa', 'Bowl',
# ...

# %%
df_drink=df2[df2.item_price<1.1]
df_drink
# Out:
#       order_id  quantity      item_name choice_description  item_price
# 28          14         1    Canned Soda       [Dr. Pepper]        1.09
# 34          17         1  Bottled Water                NaN        1.09
# 53          24         1    Canned Soda           [Sprite]        1.09
# 87          38         1  Bottled Water                NaN        1.09
# 107         47         1    Canned Soda       [Dr. Pepper]        1.09
# ...        ...       ...            ...                ...         ...
# 3936      1578         1    Canned Soda  [Diet Dr. Pepper]        1.09
# 4001      1602         1  Bottled Water                NaN        1.09
# 4008      1604         1    Canned Soda        [Diet Coke]        1.09
# 4051      1621         1    Canned Soda           [Sprite]        1.09
# 4069      1629         1  Bottled Water                NaN        1.09
#
# [106 rows x 5 columns]

# %%
df_drink.head(10)
# Out:
#      order_id  quantity      item_name choice_description  item_price
# 28         14         1    Canned Soda       [Dr. Pepper]        1.09
# 34         17         1  Bottled Water                NaN        1.09
# 53         24         1    Canned Soda           [Sprite]        1.09
# 87         38         1  Bottled Water                NaN        1.09
# 107        47         1    Canned Soda       [Dr. Pepper]        1.09
# 117        51         1    Canned Soda  [Diet Dr. Pepper]        1.09
# 126        55         1    Canned Soda        [Coca Cola]        1.09
# 179        81         1    Canned Soda        [Coca Cola]        1.09
# 180        81         1    Canned Soda       [Dr. Pepper]        1.09
# 195        87         1    Canned Soda        [Coca Cola]        1.09

# %%
df_drink.item_name.nunique()
# Out:
# 2

# %%
df_drink.item_name.value_counts()
# Out:
# Canned Soda      84
# Bottled Water    22
# Name: item_name, dtype: int64

# %%
df2[df2.item_name=='Steak Burrito']
# Out:
#       order_id  quantity      item_name  \
# 7            4         1  Steak Burrito
# 9            5         1  Steak Burrito
# 31          16         1  Steak Burrito
# 43          20         1  Steak Burrito
# 46          21         1  Steak Burrito
# ...        ...       ...            ...
# 4546      1807         1  Steak Burrito
# 4607      1829         1  Steak Burrito
# 4610      1830         1  Steak Burrito
# 4617      1833         1  Steak Burrito
# 4618      1833         1  Steak Burrito
#
#                                      choice_description  item_price
# 7     [Tomatillo Red Chili Salsa, [Fajita Vegetables...       11.75
# 9     [Fresh Tomato Salsa, [Rice, Black Beans, Pinto...        9.25
# 31    [[Roasted Chili Corn Salsa (Medium), Fresh Tom...        8.99
# 43    [Fresh Tomato Salsa, [Rice, Pinto Beans, Chees...       11.75
# 46    [Tomatillo-Red Chili Salsa (Hot), [Rice, Fajit...        8.99
# ...                                                 ...         ...
# ...

# %%
df2[df2.item_name=='Steak Burrito'].choice_description.nunique()
# Out:
# 251

# %%
df2.dropna(inplace=True)

# %%
df2[df2.choice_description.str.contains('Black Beans')].item_name.value_counts()
# Out:
# Chicken Bowl             386
# Chicken Burrito          282
# Steak Burrito            148
# Steak Bowl               110
# Veggie Bowl               60
# Veggie Burrito            55
# Chicken Salad Bowl        49
# Carnitas Bowl             39
# Barbacoa Bowl             37
# Barbacoa Burrito          30
# Carnitas Burrito          28
# Chicken Soft Tacos        19
# Chicken Crispy Tacos      14
# Veggie Salad Bowl         13
# Steak Salad Bowl          13
# Steak Soft Tacos          10
# Carnitas Soft Tacos        7
# Chicken Salad              7
# Veggie Soft Tacos          6
# Barbacoa Soft Tacos        6
# Veggie Salad               5
# Barbacoa Salad Bowl        4
# Barbacoa Crispy Tacos      3
# Carnitas Crispy Tacos      3
# Carnitas Salad Bowl        3
# Steak Crispy Tacos         2
# Steak Salad                2
# Salad                      2
# Burrito                    1
# Carnitas Salad             1
# Name: item_name, dtype: int64

# %%
df2[(df2.item_price<10) & (df2.item_name=='Chicken Bowl')]
# Out:
#       order_id  quantity     item_name  \
# 19          10         1  Chicken Bowl
# 26          13         1  Chicken Bowl
# 76          34         1  Chicken Bowl
# 78          34         1  Chicken Bowl
# 99          44         1  Chicken Bowl
# ...        ...       ...           ...
# 4583      1823         1  Chicken Bowl
# 4591      1825         1  Chicken Bowl
# 4595      1826         1  Chicken Bowl
# 4599      1827         1  Chicken Bowl
# 4604      1828         1  Chicken Bowl
#
#                                      choice_description  item_price
# 19    [Tomatillo Red Chili Salsa, [Fajita Vegetables...        8.75
# 26    [Roasted Chili Corn Salsa (Medium), [Pinto Bea...        8.49
# 76    [Fresh Tomato Salsa, [Rice, Black Beans, Pinto...        8.75
# 78    [Fresh Tomato Salsa, [Rice, Black Beans, Chees...        8.75
# 99    [Tomatillo Red Chili Salsa, [Rice, Fajita Vege...        8.75
# ...                                                 ...         ...
# ...

# %%
df2[(df2.item_price<10) & (df2.item_name=='Chicken Bowl')].sort_values(   ['item_price'])
# Out:
#       order_id  quantity     item_name  \
# 3664      1466         1  Chicken Bowl
# 2918      1160         1  Chicken Bowl
# 3101      1237         1  Chicken Bowl
# 3396      1362         1  Chicken Bowl
# 1645       665         1  Chicken Bowl
# ...        ...       ...           ...
# 1876       759         1  Chicken Bowl
# 1852       751         1  Chicken Bowl
# 1851       750         1  Chicken Bowl
# 1829       740         1  Chicken Bowl
# 4604      1828         1  Chicken Bowl
#
#                                      choice_description  item_price
# 3664  [Fresh Tomato (Mild), [Lettuce, Fajita Veggies...        8.19
# 2918  [Fresh Tomato (Mild), [Rice, Sour Cream, Cheese]]        8.19
# 3101  [Fresh Tomato (Mild), [Lettuce, Fajita Veggies...        8.19
# 3396  [Tomatillo-Green Chili Salsa (Medium), [Pinto ...        8.49
# 1645  [[Fresh Tomato Salsa (Mild), Tomatillo-Red Chi...        8.49
# ...                                                 ...         ...
# ...

# %%
df=pd.read_csv("https://raw.githubusercontent.com/nunnarilabs/ml/master/pandas/imdb_1000.csv")
df
# Out:
#      star_rating                                            title  \
# 0            9.3                         The Shawshank Redemption
# 1            9.2                                    The Godfather
# 2            9.1                           The Godfather: Part II
# 3            9.0                                  The Dark Knight
# 4            8.9                                     Pulp Fiction
# ..           ...                                              ...
# 974          7.4                                          Tootsie
# 975          7.4                      Back to the Future Part III
# 976          7.4  Master and Commander: The Far Side of the World
# 977          7.4                                      Poltergeist
# 978          7.4                                      Wall Street
#
#     content_rating      genre  duration  \
# 0                R      Crime       142
# 1                R      Crime       175
# 2                R      Crime       200
# ...

# %%
df[(df.star_rating>=8)&(df.genre=="Action")]
# Out:
#      star_rating                                           title  \
# 3            9.0                                 The Dark Knight
# 11           8.8                                       Inception
# 12           8.8  Star Wars: Episode V - The Empire Strikes Back
# 19           8.7                                       Star Wars
# 20           8.7                                      The Matrix
# 36           8.6                             Saving Private Ryan
# 37           8.6                         Raiders of the Lost Ark
# 43           8.5                           The Dark Knight Rises
# 44           8.5                                       Gladiator
# 45           8.5                      Terminator 2: Judgment Day
# 75           8.4                                          Aliens
# 80           8.4      Star Wars: Episode VI - Return of the Jedi
# 82           8.4                                      Braveheart
# ...

# %%
df[(df.star_rating>=8)&(df.genre=="Action")].sort_values(['duration'])
# Out:
#      star_rating                                           title  \
# 276          8.1                            A Fistful of Dollars
# 327          8.0                    The Adventures of Robin Hood
# 235          8.1                                         Yip Man
# 281          8.1                                  The Terminator
# 123          8.3                                     The General
# 96           8.4                                         Yojimbo
# 198          8.1                               Kill Bill: Vol. 1
# 349          8.0                                      District 9
# 391          8.0                                Edge of Tomorrow
# 239          8.1                   Elite Squad: The Enemy Within
# 37           8.6                         Raiders of the Lost Ark
# 261          8.1                                     Elite Squad
# 240          8.1                            The Bourne Ultimatum
# ...

# %%
df[df.actors_list.str.contains('Leonardo DiCaprio')]
# Out:
#      star_rating                        title content_rating      genre  \
# 11           8.8                    Inception          PG-13     Action
# 49           8.5                 The Departed              R      Crime
# 59           8.5             Django Unchained              R    Western
# 143          8.2      The Wolf of Wall Street              R  Biography
# 244          8.1               Shutter Island              R    Mystery
# 309          8.0                Blood Diamond              R  Adventure
# 340          8.0          Catch Me If You Can          PG-13  Biography
# 562          7.8  What's Eating Gilbert Grape          PG-13      Drama
# 620          7.7                      Titanic          PG-13      Drama
# 828          7.5            Gangs of New York              R      Crime
# 888          7.5                  The Aviator          PG-13  Biography
#
#      duration                                        actors_list
# ...
