# %% [markdown]
# <a href="https://colab.research.google.com/github/kirthickranjan/ML_Projects/blob/main/Gradient_Boost.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
test=pd.read_csv("https://raw.githubusercontent.com/nunnarilabs/ml/master/titanic/test.csv")
train=pd.read_csv("https://raw.githubusercontent.com/nunnarilabs/ml/master/titanic/train.csv")

# %%
train.set_index("PassengerId",inplace=True)
test.set_index("PassengerId",inplace=True)

# %%
train
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# ...

# %%
y_train=train["Survived"]

# %%
train.drop(labels="Survived",axis=1,inplace=True)

# %%
train.shape
# Out:
# (891, 10)

# %%
train_test=train.append(test)
# Out:
# <ipython-input-38-d2734cde2921>:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   train_test=train.append(test)

# %%
columns_to_drop=["Name","Age","SibSp","Ticket","Cabin","Parch","Embarked"]
train_test.drop(labels=columns_to_drop,axis=1,inplace=True)

# %%
train_test
# Out:
#              Pclass     Sex      Fare
# PassengerId
# 1                 3    male    7.2500
# 2                 1  female   71.2833
# 3                 3  female    7.9250
# 4                 1  female   53.1000
# 5                 3    male    8.0500
# ...             ...     ...       ...
# 1305              3    male    8.0500
# 1306              1  female  108.9000
# 1307              3    male    7.2500
# 1308              3    male    8.0500
# 1309              3    male   22.3583
#
# [1309 rows x 3 columns]

# %%
train_test_dummies.shape
# Out:
# (1309, 11)

# %%
train_test_dummies.isnull().sum()
# Out:
# Pclass        0
# Name          0
# Age           0
# SibSp         0
# Parch         0
# Ticket        0
# Fare          0
# Cabin         0
# Embarked      0
# Sex_female    0
# Sex_male      0
# dtype: int64

# %%
train_test_dummies.fillna(value=0.0,inplace=True)

# %%
X_train=train_test_dummies[0:891]
X_test=train_test_dummies[891:]

# %%
from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler()
X_train_scale=scaler.fit_transform(X_train)
X_test_scale=scaler.transform(X_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-49-e17e41ce5ea3> in <cell line: 3>()
#       1 from sklearn.preprocessing import MinMaxScaler
#       2 scaler=MinMaxScaler()
# ----> 3 X_train_scale=scaler.fit_transform(X_train)
#       4 X_test_scale=scaler.transform(X_test)
#
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/_set_output.py in wrapped(self, X, *args, **kwargs)
#     138     @wraps(f)
#     139     def wrapped(self, X, *args, **kwargs):
# --> 140         data_to_wrap = f(self, X, *args, **kwargs)
#     141         if isinstance(data_to_wrap, tuple):
#     142             # only wrap the first output for cross decomposition
#
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py in fit_transform(self, X, y, **fit_params)
#     876         if y is None:
#     877             # fit method of arity 1 (unsupervised transformation)
# ...

# %%
from sklearn.model_selection import train_test_split
X_train_sub,X_validation_sub,y_train_sub,y_validation_sub=train_test_split(X_train_sub,X_)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-30-52c2f2451cd3> in <cell line: 2>()
#       1 from sklearn.model_selection import train_test_split
# ----> 2 X_train_sub,X_validation_sub,y_train_sub,y_validation_sub=train_test_split(X_train_sub,X_)
#
# NameError: name 'X_train_sub' is not defined
